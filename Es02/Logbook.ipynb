# %% [markdown]
# ## **Esercitazione 02 - Logbook**
# ### **Task 1: obiettivo**
# Costruire il circuito CRRC
#
# Per costruire il circuito, abbiamo cercato di utilizzare componenti con valori il più possibile vicini a quelli richiesti, valutandoli sulla base del tempo caratteristico misurato e rimanendo all'interno del range di 50%. In particolare, abbiamo utilizzato:
# - R1 = 100 kOhm (valore nominale)
# - R2 = 1 kOhm (valore nominale)
# - C1 = (150 +- 3) nF (misurata con il tester)
# - C2 = (56 +- 2) nF (misurata con il tester)
